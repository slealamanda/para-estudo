# %% [markdown]
# <a href="https://colab.research.google.com/github/slealamanda/para-estudo/blob/main/Elei%C3%A7%C3%B5es_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Eleições 2020
#
# ***Esse notebook tem o intuito de auxiliar os meus estudos na linguagem python aplicando a Data Science***
#
# O notebook base que eu utilizei foi [esse](https://colab.research.google.com/github/programacaodinamica/analise-dados/blob/master/Eleicoes_2020.ipynb), do canal **[Programação Dinâmica](https://www.youtube.com/watch?v=gkfiZIGYllY)**

# %% [markdown]
# O conjunto de dados foi extraído da seguinte base de dados:  https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1/repositorio-de-dados-eleitorais

# %% [markdown]
# #Importando os dados

# %%
import pandas as pd
import seaborn as sns

# %%
sns.set()

# %%
cand_BRASIL = pd.read_csv("/content/drive/My Drive/Colab Datasets/eleicoes/consulta_cand_2020_BRASIL.csv")
# Out:
# b'Skipping line 11: expected 1 fields, saw 3\nSkipping line 33: expected 1 fields, saw 3\nSkipping line 42: expected 1 fields, saw 3\nSkipping line 63: expected 1 fields, saw 3\nSkipping line 75: expected 1 fields, saw 2\nSkipping line 80: expected 1 fields, saw 3\nSkipping line 85: expected 1 fields, saw 3\nSkipping line 154: expected 1 fields, saw 3\nSkipping line 160: expected 1 fields, saw 2\nSkipping line 162: expected 1 fields, saw 2\nSkipping line 168: expected 1 fields, saw 3\nSkipping line 174: expected 1 fields, saw 3\nSkipping line 185: expected 1 fields, saw 3\nSkipping line 266: expected 1 fields, saw 3\nSkipping line 313: expected 1 fields, saw 3\nSkipping line 323: expected 1 fields, saw 3\nSkipping line 330: expected 1 fields, saw 3\nSkipping line 343: expected 1 fields, saw 3\nSkipping line 381: expected 1 fields, saw 3\nSkipping line 404: expected 1 fields, saw 3\nSkipping line 440: expected 1 fields, saw 3\nSkipping line 441: expected 1 fields, saw 3\nSkipping line
# ...

# %%
cand_BRASIL

# %%
cand_BRASIL.info()

# %%
cand_BRASIL[cand_BRASIL['NM_URNA_CANDIDATO'].str.contains('BOLSONARO') == True]

# %%
cand_BRASIL['ST_REELEICAO'].value_counts(normalize=True)*100

# %%
cand_BRASIL['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)

# %%
cand_BRASIL['DS_GRAU_INSTRUCAO'].value_counts(normalize=True).plot(kind='bar', 
    title='Grau de Instrução dos candidatos 2020');

# %%
(100*cand_BRASIL['SG_PARTIDO'].value_counts(normalize=True)).plot(kind='bar', 
    figsize=(12,6), title='Candidatos por partido 2020')

# %%
cand_RJ = pd.read_csv=("/content/drive/My Drive/Colab Datasets/eleicoes/consulta_cand_2020_RJ.csv", sep=';', encoding='iso-8859-1'")
# Out:
#   File "<ipython-input-4-862d5922e882>", line 1
#     cand_RJ = pd.read_csv=("/content/drive/My Drive/Colab Datasets/eleicoes/consulta_cand_2020_RJ.csv", sep=';', encoding='iso-8859-1'")
#                                                                                                            ^
# SyntaxError: invalid syntax

# %%
cand_RJ

# %%
cand_RJ.info()

# %%
cand_RJ['ST_REELEICAO'].value_counts(normalize=True)*100

# %%
cand_RJ[cand_RJ['SG_PARTIDO'] == 'MDB']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)*100

# %%
#replicar o codigo de cima para os outros partidos
